# %%
import pandas as pd
import numpy as np
import os
import pickle

global PATH
#PATH = '/content/drive/MyDrive/Colab Notebooks/final/enron_sent/'
PATH = ''

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%time
texts = []
users = []
folders = []
import time
start_time = time.time()
for top, dirs, files in os.walk(PATH + 'data\maildir'): #https://www.cs.cmu.edu/~enron/enron_mail_20150507.tar.gz
    if len(top.split("\\")) == 4 and 'sent' in top.split("\\")[3]:
        for file in files:
            print(top.split("\\")[2])
            text = np.array(open(os.path.join(top, file)).readlines())
            indice = np.argwhere(np.char.startswith(text,'X-FileName:'))[0][0] + 1
            texts.append(' '.join(text[indice:]))
            users.append(top.split("\\")[2])
            folders.append(top.split("\\")[3])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# ...

# %%
df = pd.DataFrame({'text':texts,'user':users,'folder':folders})
df.head()
# Out:
#                                                 text     user folder
# 0  \n ---------------------- Forwarded by Phillip...  allen-p   sent
# 1  \n ---------------------- Forwarded by Phillip...  allen-p   sent
# 2  \n Larry,\n \n  Just a note to touch base on t...  allen-p   sent
# 3  \n Ina,\n \n  I scheduled a meeting with Jean ...  allen-p   sent
# 4  \n ---------------------- Forwarded by Phillip...  allen-p   sent

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126057 entries, 0 to 126056
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   text    126057 non-null  object
#  1   user    126057 non-null  object
#  2   folder  126057 non-null  object
# dtypes: object(3)
# memory usage: 2.9+ MB

# %%
df.user.value_counts().nlargest(49)
# Out:
# mann-k           8926
# kaminski-v       8644
# dasovich-j       5366
# germany-c        5128
# shackleton-s     4407
# jones-t          4123
# bass-e           3030
# lenhart-m        2759
# beck-s           2674
# symes-k          2649
# scott-s          2602
# taylor-m         2409
# love-p           2371
# arnold-j         2353
# perlingiere-d    2352
# nemec-g          2175
# fossum-d         2067
# sanders-r        2035
# giron-d          1880
# lavorato-j       1868
# kean-s           1834
# rogers-b         1822
# delainey-d       1814
# mcconnell-m      1756
# farmer-d         1715
# allen-p          1509
# sager-e          1476
# rodrique-r       1442
# steffes-j        1379
# stclair-c        1328
# kitchen-l        1132
# dorland-c        1129
# cash-m           1128
# haedicke-m       1104
# neal-s           1102
# shankman-j       1084
# blair-l           978
# watson-k          971
# presto-k          963
# ward-k            899
# grigsby-m         858
# ...

# %%
len(df)
# Out:
# 126057

# %%
df_sent = df.copy()

# %%
for val, cnt in df.user.value_counts().iteritems():
    if (cnt < 3000 or cnt > 9000):
        df_sent = df_sent[df_sent.user != val]

# %%
df_sent.user.value_counts()
# Out:
# mann-k          8926
# kaminski-v      8644
# dasovich-j      5366
# germany-c       5128
# shackleton-s    4407
# jones-t         4123
# bass-e          3030
# Name: user, dtype: int64

# %%
len(df_sent)
# Out:
# 126057

# %%
len(df_sent)
# Out:
# 39624

# %%
df_sent.user.value_counts()
# Out:
# mann-k          8926
# kaminski-v      8644
# dasovich-j      5366
# germany-c       5128
# shackleton-s    4407
# jones-t         4123
# bass-e          3030
# Name: labels, dtype: int64

# %%
df_sent.to_csv(PATH + 'data/data_users_as_labels-sent.csv')

# Use pickle to save space
pickle.dump(open(PATH + 'en/data/en_df', 'wb'))
