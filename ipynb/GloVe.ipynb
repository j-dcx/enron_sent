# %%
#https://towardsdatascience.com/a-comprehensive-python-implementation-of-glove-c94257c2813d
#https://github.com/pengyan5gensim10/nlp-paper-implementation

# %%
# !pip install gensim --upgrade --quiet

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/final/enron_sent/visualization/glove/'
# Out:
# /content/drive/MyDrive/Colab Notebooks/final/enron_sent/visualization/glove

# %%
#!git clone https://github.com/pengyan510/nlp-paper-implementation
# Out:
# Cloning into 'nlp-paper-implementation'...
# remote: Enumerating objects: 61, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 61 (delta 24), reused 49 (delta 15), pack-reused 0
# Unpacking objects: 100% (61/61), done.

# %%
import pickle
vocab = pickle.load(open('/content/drive/MyDrive/Colab Notebooks/final/enron_sent/visualization/texts/word2vec_flat','rb'))

# %%
len(vocab)
# Out:
# 470678

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/final/enron_sent/visualization/glove/nlp-paper-implementation/glove/src/'
# Out:
# /content/drive/MyDrive/Colab Notebooks/final/enron_sent/visualization/glove/nlp-paper-implementation/glove/src

# %%
# !pip install -U PyYAML --quiet

# %%
import yaml
yaml.__version__
# Out:
# '6.0'

# %%
# %%time
# !python train.py --first-step-only
# Out:
#   0% 0/10 [00:00<?, ?it/s]
#   0% 0/470678 [00:00<?, ?it/s]
#   2% 11153/470678 [00:00<00:05, 80207.59it/s]
#   8% 39789/470678 [00:00<00:02, 184669.50it/s]
#  14% 63732/470678 [00:00<00:01, 207659.31it/s]
#  19% 88796/470678 [00:00<00:01, 223770.21it/s]
#  25% 115783/470678 [00:00<00:01, 239844.02it/s]
#  30% 142884/470678 [00:00<00:01, 250201.13it/s]
#  36% 168284/470678 [00:00<00:01, 250908.36it/s]
#  41% 193631/470678 [00:00<00:01, 245075.70it/s]
#  47% 219036/470678 [00:00<00:01, 247791.84it/s]
#  52% 245207/470678 [00:01<00:00, 251999.24it/s]
#  58% 271025/470678 [00:01<00:00, 253860.72it/s]
#  63% 296489/470678 [00:01<00:00, 253109.28it/s]
#  68% 321854/470678 [00:01<00:00, 247186.27it/s]
#  74% 347729/470678 [00:01<00:00, 250585.78it/s]
#  79% 372841/470678 [00:01<00:00, 224197.58it/s]
#  85% 399580/470678 [00:01<00:00, 236047.21it/s]
#  91% 426628/470678 [00:01<00:00, 245746.12it/s]
# 100% 470678/470678 [00:01<00:00, 239244.58it/s]
#  10% 1/10 [00:02<00:26,  2.92s/it]
# ...

# %%
# %%time
main('--second-step-only')
# Out:
# Streaming output truncated to the last 5000 lines.
# 19276it [04:03, 81.80it/s]
# 19285it [04:03, 81.12it/s]
# 19294it [04:03, 80.75it/s]
# 19303it [04:04, 81.76it/s]
# 19312it [04:04, 81.43it/s]
# 19321it [04:04, 81.64it/s]
# 19330it [04:04, 82.81it/s]
# 19339it [04:04, 83.50it/s]
# 19348it [04:04, 83.23it/s]
# 19357it [04:04, 84.25it/s]
# 19366it [04:04, 83.81it/s]
# 19375it [04:04, 80.60it/s]
# 19384it [04:05, 80.08it/s]
# 19393it [04:05, 80.53it/s]
# 19402it [04:05, 81.20it/s]
# 19411it [04:05, 81.96it/s]
# 19420it [04:05, 83.00it/s]
# 19429it [04:05, 83.14it/s]
# 19438it [04:05, 83.41it/s]
# 19447it [04:05, 82.83it/s]
# 19456it [04:05, 83.63it/s]
# 19465it [04:06, 82.33it/s]
# 19474it [04:06, 82.60it/s]
# 19483it [04:06, 82.29it/s]
# 19492it [04:06, 82.53it/s]
# 19501it [04:06, 83.18it/s]
# 19510it [04:06, 83.23it/s]
# 19519it [04:06, 81.09it/s]
# 19528it [04:06, 81.72it/s]
# 19537it [04:06, 82.71it/s]
# 19546it [04:07, 82.71it/s]
# 19555it [04:07, 80.43it/s]
# ...
