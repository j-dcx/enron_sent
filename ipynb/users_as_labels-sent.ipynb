# %%
import pandas as pd
import numpy as np
import os

# %%
c=0
for i in os.walk('data\enron_mail_20150507\maildir'):
    c+=1
print(c)
# Out:
# 3500

# %%
features = []
labels = []
folders = []
import time
start_time = time.time()
for top, dirs, files in os.walk('data\enron_mail_20150507\maildir'):
    print(top)
# Out:
# data\enron_mail_20150507\maildir
# data\enron_mail_20150507\maildir\allen-p
# data\enron_mail_20150507\maildir\allen-p\all_documents
# data\enron_mail_20150507\maildir\allen-p\contacts
# data\enron_mail_20150507\maildir\allen-p\deleted_items
# data\enron_mail_20150507\maildir\allen-p\discussion_threads
# data\enron_mail_20150507\maildir\allen-p\inbox
# data\enron_mail_20150507\maildir\allen-p\notes_inbox
# data\enron_mail_20150507\maildir\allen-p\sent
# data\enron_mail_20150507\maildir\allen-p\sent_items
# data\enron_mail_20150507\maildir\allen-p\straw
# data\enron_mail_20150507\maildir\allen-p\_sent_mail
# data\enron_mail_20150507\maildir\arnold-j
# data\enron_mail_20150507\maildir\arnold-j\2000_conference
# data\enron_mail_20150507\maildir\arnold-j\active_international
# data\enron_mail_20150507\maildir\arnold-j\all_documents
# data\enron_mail_20150507\maildir\arnold-j\avaya
# data\enron_mail_20150507\maildir\arnold-j\bmc
# data\enron_mail_20150507\maildir\arnold-j\bridge
# ...

# %%
texts = []
users = []
folders = []
import time
start_time = time.time()
for top, dirs, files in os.walk('data\enron_mail_20150507\maildir'):
    #print(top)
    if len(top.split("\\")) == 5 and 'sent' in top.split("\\")[4]:
        for file in files:
            #print(os.path.join(top, file))
            print(top.split("\\")[3])
            text = np.array(open(os.path.join(top, file)).readlines())
            indice = np.argwhere(np.char.startswith(feature,'X-FileName:'))[0][0] + 1
            texts.append(' '.join(feature[indice:]))
            users.append(top.split("\\")[3])
            folders.append(top.split("\\")[4])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# allen-p
# ...

# %%
df = pd.DataFrame({'text':texts,'user':users,'folders':folders})
df.head()
# Out:
#                                                 text     user folders
# 0  \n I will have 4 books:\n \n CAND-MGMT-BAS for...  allen-p    sent
# 1  \n I will have 4 books:\n \n CAND-MGMT-BAS for...  allen-p    sent
# 2  \n I will have 4 books:\n \n CAND-MGMT-BAS for...  allen-p    sent
# 3  \n I will have 4 books:\n \n CAND-MGMT-BAS for...  allen-p    sent
# 4  \n I will have 4 books:\n \n CAND-MGMT-BAS for...  allen-p    sent

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126057 entries, 0 to 126056
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   text     126057 non-null  object
#  1   user     126057 non-null  object
#  2   folders  126057 non-null  object
# dtypes: object(3)
# memory usage: 2.9+ MB

# %%
df.user.value_counts().nlargest(49)
# Out:
# mann-k           8926
# kaminski-v       8644
# dasovich-j       5366
# germany-c        5128
# shackleton-s     4407
# jones-t          4123
# bass-e           3030
# lenhart-m        2759
# beck-s           2674
# symes-k          2649
# scott-s          2602
# taylor-m         2409
# love-p           2371
# arnold-j         2353
# perlingiere-d    2352
# nemec-g          2175
# fossum-d         2067
# sanders-r        2035
# giron-d          1880
# lavorato-j       1868
# kean-s           1834
# rogers-b         1822
# delainey-d       1814
# mcconnell-m      1756
# farmer-d         1715
# allen-p          1509
# sager-e          1476
# rodrique-r       1442
# steffes-j        1379
# stclair-c        1328
# kitchen-l        1132
# dorland-c        1129
# cash-m           1128
# haedicke-m       1104
# neal-s           1102
# shankman-j       1084
# blair-l           978
# watson-k          971
# presto-k          963
# ward-k            899
# grigsby-m         858
# ...

# %%
len(df)
# Out:
# 126057

# %%
df_sent = df.copy()
for val, cnt in df_sent.user.value_counts().iteritems():
    if (cnt < 2500 or cnt > 3000):
        df_sent = df_sent[df_sent.user != val]
print(len(df_sent))
# Out:
# 10684

# %%
df_sent.user.value_counts()
# Out:
# lenhart-m    2759
# beck-s       2674
# symes-k      2649
# scott-s      2602
# Name: user, dtype: int64

# %%
df_sent.to_csv('data_users_as_labels-sent.csv')
