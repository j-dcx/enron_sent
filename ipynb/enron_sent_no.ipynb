# %% [markdown]
# ### Initialize variables

# %%
lang = 'no'
sg = 1
#architecture = 'mlp'
#architecture = 'cnn'
architecture = 'lstm'
#vector = 'word2vec_skipgram'
#vector = 'word2vec_cbow'
#vector = 'spacy'
vector = 'tfkerastokenizer'
#vector = 'tfidf_hashing_vectorizer'
optimizer_name = 'sgd'
#optimizer_name = 'adam'

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/final/enron_sent/'

import os
global PATH
PATH = os.getcwd() + '/'

# !pip install import-ipynb -q
import import_ipynb

import include as i
spacy_path = i.spacy_paths[lang]
stopwords_lang = i.stopwords_langs[lang]
# Out:
# /content/drive/MyDrive/Colab Notebooks/final/enron_sent
#      |████████████████████████████████| 1.6 MB 14.8 MB/s
# importing Jupyter notebook from include.ipynb

# %% [markdown]
# ### Initialize libraries

# %%
import base64
import keras.backend as K
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
import re
import seaborn as sns
import string
import tensorflow as tf
import time

import nltk
nltk.download('stopwords')

import spacy

from collections import Counter
from keras.layers import Dense, Dropout, Input, LSTM, Embedding, Bidirectional, Flatten, SpatialDropout1D, Conv1D, MaxPooling1D, GlobalMaxPooling1D
from keras.models import Sequential, Model
from keras_preprocessing.sequence import pad_sequences
from sklearn.metrics import log_loss
from sklearn.preprocessing import normalize
from sklearn.model_selection import train_test_split
from tensorflow.keras.metrics import Accuracy,Precision,Recall,AUC,CategoricalAccuracy,CategoricalCrossentropy,CategoricalHinge
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.preprocessing.text import Tokenizer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#https://aakashgoel12.medium.com/how-to-add-user-defined-function-get-f1-score-in-keras-metrics-3013f979ce0d
def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

#https://stackoverflow.com/questions/49284455/keras-custom-function-implementing-jaccard
def jaccard_score(y_true, y_pred, smooth=100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.abs(y_true) + K.abs(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac/100 * smooth

# %% [markdown]
# ### Initialize language

# %%
from nltk.corpus import stopwords
stopwords = stopwords.words(stopwords_lang)

# %%
nlp = spacy.load(PATH + lang + spacy_path)

# %% [markdown]
# ### Load data

# %%
# %%time
df_orig = pd.read_csv(PATH + 'data/users_as_labels_sent.csv')
# Use pickle to save space
#df_orig = pickle.load( open( PATH + 'data/df_' + lang, 'rb' ) ) # Preprocessed df
#df_orig = pickle.load( open( PATH + lang + '/data/df_' + lang, 'rb' ) ) # Ready df
# Out:
# CPU times: user 493 ms, sys: 133 ms, total: 626 ms
# Wall time: 1.42 s

# %%
df_orig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39624 entries, 0 to 39623
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    39624 non-null  object
#  1   user    39624 non-null  object
#  2   folder  39624 non-null  object
# dtypes: object(3)
# memory usage: 928.8+ KB

# %%
df_orig.head()
# Out:
#                                                 text    user folder
# 0  \n I don't know if you got these.\n ----------...  bass-e   sent
# 1  \n Can you spell S-N-O-O-T-Y?\n \n e\n \n \n  ...  bass-e   sent
# 2      \n The new deal #s are 147888,147889.\n \n -E  bass-e   sent
# 3  \n I think I sent this to the worng e-mail add...  bass-e   sent
# 4  \n We are going to Woody's tonight if you are ...  bass-e   sent

# %%
df_orig.user.value_counts()
# Out:
# mann-k          8926
# kaminski-v      8644
# dasovich-j      5366
# germany-c       5128
# shackleton-s    4407
# jones-t         4123
# bass-e          3030
# Name: user, dtype: int64

# %%
df = df_orig.copy()

# %% [markdown]
# ### Translate

# %%
df['lang'] = lang
df['length'] = df.text.apply(lambda x: len(x))

# %% [markdown]
# #### Do translate

# %%
# !pip install googletrans==3.1.0a0 -q

# %%
from googletrans import Translator
translator = Translator()

# %%
#Find if some features are too long for Google to translate
df.length.value_counts().sort_index(ascending=False)

# %%
# %%time
translations = []
for key in df.index:
  if key == 3430:
    line = line[:145900] # Experimentally established that max character limit Google can translate is ~145900
  else:
    line = df.text[key]
  translations.append(translator.translate(line, src = 'en', dest=lang).text)

# %%
df['translation'] = translations
#df['translation'] = df.text # No need, because language already is EN

# %%
df['length'] = df.translation.apply(lambda x: len(x))

# %% [markdown]
# #### Save translate

# %%
# Use pickle to save space
pickle.dump(df, open(PATH + lang + '/data/df_' + lang, 'wb'))

# %% [markdown]
# #### Load translate

# %%
df = pickle.load(open(PATH + lang + '/data/df_' + lang, 'rb'))

# %% [markdown]
# ###Spacy

# %%
#https://www.kaggle.com/code/enerrio/scary-nlp-with-spacy-and-keras/notebook

# %%
# Clean text before feeding it to Spacy
punctuations = string.punctuation
from collections import defaultdict

# Define function to cleanup text by removing personal pronouns, stopwords, and puncuation
def cleanup_text(docs, logging=False):
    texts = []
    counter = 1
    for doc in docs:
        if counter % 1000 == 0 and logging:
            print("Processed %d out of %d documents." % (counter, len(docs)))
        counter += 1
        doc = nlp(doc, disable=['parser', 'ner'])
        tokens = [tok.lemma_.lower().strip() for tok in doc if tok.lemma_ != '-PRON-']
        tokens = [tok for tok in tokens if tok not in stopwords and tok not in punctuations]
        
        tokens = ' '.join(tokens)
        texts.append(tokens)
    return pd.Series(texts)

# %%
# %%time
# Cleanup text and make sure it retains original shape
print('Original training data shape: ', df.translation.shape)
train_cleaned = cleanup_text(df.translation, logging=True)
print('Cleaned up training data shape: ', train_cleaned.shape)

# %%
pickle.dump(train_cleaned, open(PATH + lang + '/texts/spacy_' + lang, 'wb'))

# %%
train_cleaned = pickle.load(open(PATH + lang + '/texts/spacy_' + lang, 'rb'))

# %%
df['translation_clean'] = train_cleaned.values

# %%
df.translation_clean.isna().sum()
# Out:
# 0

# %%
df.translation_clean.fillna(' ', inplace=True)

# %%
# Use pickle to save space
pickle.dump( df, open( PATH + lang + '/data/df_' + lang, 'wb' ) )

# %%
# Use pickle to save space
df = pickle.load( open( PATH + lang + '/data/df_' + lang, 'rb' ) )

# %%
# %%time
# Parse documents and print some info
print('Parsing documents...')

train_vec = []
c = 0
for doc in nlp.pipe(df.translation_clean, batch_size=500):
    if doc.has_vector:
        train_vec.append(doc.vector)
    # If doc doesn't have a vector, then fill it with zeros.
    else:
        train_vec.append(np.zeros((300,), dtype="float32"))
    if c%100 == 0: print(f'c: {c}')
    c+=1
        
# train_vec = [doc.vector for doc in nlp.pipe(train_cleaned, batch_size=500)]
train_vec = np.array(train_vec)

print('Total number of documents parsed: {}'.format(len(train_vec)))
print('Number of words in first document: ', len(df.translation_clean.iloc[0]))
print('Number of words in second document: ', len(df.translation_clean.iloc[1]))

# %%
train_vec.shape

# %%
train_vec[0]

# %%
pickle.dump(train_vec,open(PATH + lang + '/vectors/spacy_' + lang, 'wb'))

# %%
train_vec = pickle.load(open(PATH + lang + '/vectors/spacy_' + lang, 'rb'))

# %% [markdown]
# ###Word2vec

# %%
all_text = pd.DataFrame({'text_clean':df.text_clean})
print('Number of total text documents:', len(all_text))

# %%
# Define function to preprocess text for a word2vec model
def cleanup_text_word2vec(docs, logging=False):
    sentences = []
    counter = 1
    for doc in docs:
        if counter % 1000 == 0 and logging:
            print("Processed %d out of %d documents" % (counter, len(docs)))
        # Disable tagger so that lemma_ of personal pronouns (I, me, etc) don't getted marked as "-PRON-"
        doc = nlp(doc, disable=['tagger'])
        # Grab lemmatized form of words and make lowercase
        doc = " ".join([tok.lemma_.lower() for tok in doc])
        # Split into sentences based on punctuation
        doc = re.split("[\.?!;] ", doc)
        # Remove commas, periods, and other punctuation (mostly commas)
        doc = [re.sub("[\.,;:!?]", "", sent) for sent in doc]
        # Split into words
        doc = [sent.split() for sent in doc]
        sentences += doc
        counter += 1
    return sentences

# %%
# %%time
train_cleaned_word2vec = cleanup_text_word2vec(all_text.text_clean, logging=True)
print('Cleaned up training data size (i.e. number of sentences): ', len(train_cleaned_word2vec))

# %%
pickle.dump(train_cleaned_word2vec,open(PATH + lang + '/texts/word2vec_' + lang, 'wb'))

# %%
train_cleaned_word2vec = pickle.load(open(PATH + lang + '/texts/word2vec_' + lang, 'rb'))

# %%
train_cleaned_word2vec[0]

# %%
# !pip install gensim -U -q

# %%
import gensim

# %%
gensim.__version__

# %%
# %%time
from gensim.models.word2vec import Word2Vec

text_dim = 300
print("Training Word2Vec model...")
wordvec_model = Word2Vec(train_cleaned_word2vec, vector_size=text_dim, window=5, min_count=3, workers=4, sg=sg)
print("Word2Vec model created.")
# Out:
# Training Word2Vec model...
# Word2Vec model created.
# CPU times: user 4min 8s, sys: 783 ms, total: 4min 9s
# Wall time: 1min 25s

# %%
print("%d unique words represented by %d dimensional vectors" % (len(wordvec_model.wv.key_to_index), text_dim))

# %%
pickle.dump(wordvec_model,open(PATH + lang + '/models/vector/' + vector + '_30k_300d_' + lang, 'wb'))

# %%
wordvec_model = pickle.load(open(PATH + lang + '/models/vector/' + vector + '_30k_300d_' + lang, 'rb'))

# %%
print(wordvec_model.wv.most_similar(positive=['presentation', 'scheduled'], negative=['market']))
print(wordvec_model.wv.most_similar_cosmul(positive=['presentation', 'scheduled'], negative=['market']))
print(wordvec_model.wv.doesnt_match("Please read the following".split()))
print(wordvec_model.wv.similarity('presentation', 'scheduled'))

# %%
# Define function to create word vectors given a cleaned piece of text.
def create_average_vec(doc):
    average = np.zeros((text_dim,), dtype='float32')
    num_words = 0.
    for word in doc.split():
        if word in wordvec_model.wv.key_to_index:
            average = np.add(average, wordvec_model.wv.get_vector(word))
            num_words += 1.
    if num_words != 0.:
        average = np.divide(average, num_words)
    return average

# %%
# Counting the number of empty strings are in df.translation_clean
count = 0
for i in range(len(df.translation_clean)):
    if df.translation_clean.iloc[i] == "":
        print("index:", i)
        count += 1
print(count)

# %%
# %%time
# Create word vectors
text_dim = 300
train_cleaned_vec = np.zeros((df.translation_clean.shape[0], text_dim), dtype="float32")  # 19579 x 300
df.translation_clean.fillna('', inplace=True)
for i in range(len(df.translation_clean)):
    train_cleaned_vec[i] = create_average_vec(df.translation_clean.iloc[i])

print("Train word vector shape:", train_cleaned_vec.shape)

# %%
pickle.dump(train_cleaned_vec, open(PATH + lang + '/vectors/' + vector + '_30k_300d_' + lang, 'wb'))

# %%
train_cleaned_vec = pickle.load(open(PATH + lang + '/vectors/' + vector + '_30k_300d_' + lang, 'rb'))

# %% [markdown]
# ###Define X and y

# %% [markdown]
# ####Spacy

# %%
# Spacy
X = train_vec
#X = normalize(train_vec, norm='max') # Sometimes returns better results if vecors are normalized
y = pd.get_dummies(df.user).values

# %%
X[0]

# %% [markdown]
# ####Word2Vec

# %%
# Word2Vec
X = train_cleaned_vec
y = pd.get_dummies(df.user).values

# %%
X.shape
# Out:
# (39624, 300)

# %% [markdown]
# ####Tokenizer

# %%
def get_sequences(texts, tokenizer, train=True, max_seq_length=None):
    sequences = tokenizer.texts_to_sequences(texts)
    
    if train == True:
        max_seq_length = np.max(list(map(lambda x: len(x), sequences)))
        print('max_seq_length: '+str(max_seq_length))
    
    sequences = pad_sequences(sequences, maxlen=300, padding='post')
    
    return sequences

# %%
# %%time
tokenizer = Tokenizer(num_words=30000, lower=True)
tokenizer.fit_on_texts(df.translation_clean.values)
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
X = get_sequences(df.translation_clean.values, tokenizer, train=True)
y = np.array(pd.get_dummies(df.user))
# Out:
# Found 129353 unique tokens.
# max_seq_length: 21506
# CPU times: user 17.5 s, sys: 172 ms, total: 17.7 s
# Wall time: 18.1 s

# %% [markdown]
# ####Hashingvectorizer

# %%
# %%time
from sklearn.feature_extraction.text import HashingVectorizer
features_hash = HashingVectorizer(ngram_range=(1,2),n_features=300).transform(df.translation_clean)
features_matrix = features_hash
# Out:
# CPU times: user 10.6 s, sys: 164 ms, total: 10.8 s
# Wall time: 12.7 s

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer().fit(features_matrix)

# %%
# %%time
X = tfidf_transformer.transform(features_matrix).toarray()
y = pd.get_dummies(df.user).values
# Out:
# CPU times: user 151 ms, sys: 1.96 ms, total: 153 ms
# Wall time: 158 ms

# %%
X.shape
# Out:
# (39624, 300)

# %% [markdown]
# ###Define model

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)
print('X_train size: {}'.format(X_train.shape))
print('X_test size: {}'.format(X_test.shape))
print('y_train size: {}'.format(y_train.shape))
print('y_test size: {}'.format(y_test.shape))
# Out:
# X_train size: (27736, 300)
# X_test size: (11888, 300)
# y_train size: (27736, 7)
# y_test size: (11888, 7)

# %%
def build_model(architecture='mlp'):
    model = Sequential()
    if architecture == 'mlp':
        # Densely Connected Neural Network (Multi-Layer Perceptron)
        model.add(Dense(512, activation='relu', kernel_initializer='he_normal', input_dim=X_train[0].shape[0]))
        model.add(Dropout(0.2))
        model.add(Dense(512, activation='relu', kernel_initializer='he_normal'))
        model.add(Dropout(0.2))
        model.add(Dense(512, activation='relu', kernel_initializer='he_normal'))
        model.add(Dropout(0.2))
        model.add(Dense(512, activation='relu', kernel_initializer='he_normal'))
        model.add(Dropout(0.2))
        #model.add(Dense(3, activation='softmax'))
        model.add(Dense(y_train.shape[1], activation='softmax'))
    elif architecture == 'cnn':
        # 1-D Convolutional Neural Network
        inputs = Input(shape=(X_train[0].shape[0],1))

        x = Conv1D(64, 3, strides=1, padding='same', activation='relu')(inputs)

        #Cuts the size of the output in half, maxing over every 2 inputs
        x = MaxPooling1D(pool_size=2)(x)
        x = Conv1D(128, 3, strides=1, padding='same', activation='relu')(x)
        x = GlobalMaxPooling1D()(x) 
        outputs = Dense(y_train.shape[1], activation='softmax')(x)

        model = Model(inputs=inputs, outputs=outputs, name='CNN')
    elif architecture == 'lstm':
        # LSTM network
        inputs = Input(shape=(X_train[0].shape[0],))
        embedding = Embedding(input_dim=30000,output_dim=64)(inputs)
        #lstm1 = Bidirectional(LSTM(256,input_length=X_train.shape[1],return_sequences=True,dropout=0.2,recurrent_dropout=0,activation="tanh",recurrent_activation="sigmoid",unroll=False,use_bias=True))(embedding)
        lstm1 = LSTM(256,input_length=X_train.shape[1],return_sequences=True,dropout=0.2,recurrent_dropout=0,activation="tanh",recurrent_activation="sigmoid",unroll=False,use_bias=True)(embedding)
        #lstm2 = tf.keras.layers.LSTM(128, dropout=0.2, recurrent_dropout=0, activation="tanh",recurrent_activation="sigmoid",unroll=False,use_bias=True)(lstm1)
        flatten = Flatten()(lstm1)
        #outputs = Dense(y_train.shape[1], activation='sigmoid')(flatten)
        outputs = Dense(y_train.shape[1], activation='softmax')(flatten)
        model = Model(inputs=inputs, outputs=outputs)

        #model = Sequential()
        #model.add(Embedding(30000, 64, input_length=X_train.shape[1]))
        #model.add(SpatialDropout1D(0.2))
        #model.add(LSTM(256,input_length=X_train.shape[1],return_sequences=False,dropout=0.2,recurrent_dropout=0,activation="tanh",recurrent_activation="sigmoid",unroll=False,use_bias=True))
        #model.add(LSTM(256, dropout=0.2, recurrent_dropout=0, activation="tanh",recurrent_activation="sigmoid",unroll=False,use_bias=True))
        #model.add(Dense(y_train.shape[1], activation='softmax'))
    else:
        print('Error: Model type not found.')
    return model

# %%
# Define keras model
# Using MLP in kernel for speed
#model = build_model('mlp')
#model = build_model('cnn')
#model = build_model('lstm')
model = build_model(architecture)

# If the model is a CNN then expand the dimensions of the training data
#if model.name == "CNN" or model.name == "LSTM":
if model.name == "CNN":
    X_train = np.expand_dims(X_train, axis=2)
    X_test = np.expand_dims(X_test, axis=2)
    print('Text train shape: ', X_test.shape)
    print('Text test shape: ', X_test.shape)
    
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 300)]             0
#
#  embedding (Embedding)       (None, 300, 64)           1920000
#
#  lstm (LSTM)                 (None, 300, 256)          328704
#
#  flatten (Flatten)           (None, 76800)             0
#
#  dense (Dense)               (None, 7)                 537607
#
# =================================================================
# Total params: 2,786,311
# Trainable params: 2,786,311
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
adam = Adam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=False,
    name='Adam',
)
model.compile(optimizer=sgd,
              loss='categorical_crossentropy',
              metrics=[
                        'accuracy',
                        Precision(),
                        Recall(),
                        get_f1,
                        jaccard_score,
                        AUC(),
                        CategoricalAccuracy(),
                        CategoricalCrossentropy(),
                        CategoricalHinge()
                        ])
#Accuracy()

# %% [markdown]
# ###Train model

# %%
# %%time
start_time = time.time()

# Define number of epochs
epochs = 50

# Fit the model to the training data
estimator = model.fit(X_train, y_train,
                      validation_split=0.2,
                      epochs=epochs,
                      batch_size=128,
                      verbose=1,
                      validation_data=(X_test, y_test),
                      callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5,restore_best_weights=True,min_delta=0.001,verbose=1)]
                      )

execution_time = time.time() - start_time
# Out:
# Epoch 1/50
# 217/217 [==============================] - 673s 3s/step - loss: 1.8573 - accuracy: 0.2528 - precision: 0.0000e+00 - recall: 0.0000e+00 - get_f1: 0.0000e+00 - jaccard_score: 0.9837 - auc: 0.6382 - categorical_accuracy: 0.2528 - categorical_crossentropy: 1.8573 - categorical_hinge: 1.0618 - val_loss: 1.8289 - val_accuracy: 0.3036 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_get_f1: 0.0000e+00 - val_jaccard_score: 0.9837 - val_auc: 0.6646 - val_categorical_accuracy: 0.3036 - val_categorical_crossentropy: 1.8289 - val_categorical_hinge: 1.0477
# Epoch 2/50
# 217/217 [==============================] - 648s 3s/step - loss: 1.5633 - accuracy: 0.4134 - precision: 0.8757 - recall: 0.1613 - get_f1: 0.2506 - jaccard_score: 0.9860 - auc: 0.7658 - categorical_accuracy: 0.4134 - categorical_crossentropy: 1.5633 - categorical_hinge: 0.9371 - val_loss: 1.4850 - val_accuracy: 0.4383 - val_precision: 0.5760 - val_recall: 0.3461 - val_get_f1: 0.4317 - val_jaccard_score: 0.9886 - val_auc: 0.8181 - val_categorical_accuracy: 0.4383 - val_categorical_crossentropy: 1.4850 - val_categorical_hinge: 0.8803
# Epoch 3/50
# 217/217 [==============================] - 646s 3s/step - loss: 1.0759 - accuracy: 0.6190 - precision: 0.9240 - recall: 0.4144 - get_f1: 0.5635 - jaccard_score: 0.9900 - auc: 0.8997 - categorical_accuracy: 0.6190 - categorical_crossentropy: 1.0759 - categorical_hinge: 0.6995 - val_loss: 0.7464 - val_accuracy: 0.7389 - val_precision: 0.9334 - val_recall: 0.5834 - val_get_f1: 0.7172 - val_jaccard_score: 0.9924 - val_auc: 0.9563 - val_categorical_accuracy: 0.7389 - val_categorical_crossentropy: 0.7464 - val_categorical_hinge: 0.5563
# Epoch 4/50
# 217/217 [==============================] - 648s 3s/step - loss: 0.6129 - accuracy: 0.7928 - precision: 0.9364 - recall: 0.7004 - get_f1: 0.7997 - jaccard_score: 0.9942 - auc: 0.9672 - categorical_accuracy: 0.7928 - categorical_crossentropy: 0.6129 - categorical_hinge: 0.4386 - val_loss: 0.4926 - val_accuracy: 0.8419 - val_precision: 0.9582 - val_recall: 0.7842 - val_get_f1: 0.8621 - val_jaccard_score: 0.9954 - val_auc: 0.9787 - val_categorical_accuracy: 0.8419 - val_categorical_crossentropy: 0.4926 - val_categorical_hinge: 0.3528
# Epoch 5/50
# 217/217 [==============================] - 645s 3s/step - loss: 0.4616 - accuracy: 0.8480 - precision: 0.9473 - recall: 0.7912 - get_f1: 0.8620 - jaccard_score: 0.9957 - auc: 0.9808 - categorical_accuracy: 0.8480 - categorical_crossentropy: 0.4616 - categorical_hinge: 0.3308 - val_loss: 0.3570 - val_accuracy: 0.8756 - val_precision: 0.9664 - val_recall: 0.8287 - val_get_f1: 0.8920 - val_jaccard_score: 0.9966 - val_auc: 0.9886 - val_categorical_accuracy: 0.8756 - val_categorical_crossentropy: 0.3570 - val_categorical_hinge: 0.2632
# Epoch 6/50
# 217/217 [==============================] - 650s 3s/step - loss: 0.3935 - accuracy: 0.8680 - precision: 0.9474 - recall: 0.8220 - get_f1: 0.8801 - jaccard_score: 0.9964 - auc: 0.9858 - categorical_accuracy: 0.8680 - categorical_crossentropy: 0.3935 - categorical_hinge: 0.2882 - val_loss: 0.6263 - val_accuracy: 0.8308 - val_precision: 0.8590 - val_recall: 0.8136 - val_get_f1: 0.8355 - val_jaccard_score: 0.9961 - val_auc: 0.9660 - val_categorical_accuracy: 0.8308 - val_categorical_crossentropy: 0.6263 - val_categorical_hinge: 0.3493
# Epoch 7/50
# 217/217 [==============================] - 646s 3s/step - loss: 0.3322 - accuracy: 0.8891 - precision: 0.9522 - recall: 0.8502 - get_f1: 0.8981 - jaccard_score: 0.9969 - auc: 0.9896 - categorical_accuracy: 0.8891 - categorical_crossentropy: 0.3322 - categorical_hinge: 0.2480 - val_loss: 0.4884 - val_accuracy: 0.8438 - val_precision: 0.8943 - val_recall: 0.8210 - val_get_f1: 0.8560 - val_jaccard_score: 0.9963 - val_auc: 0.9794 - val_categorical_accuracy: 0.8438 - val_categorical_crossentropy: 0.4884 - val_categorical_hinge: 0.3123
# Epoch 8/50
# 217/217 [==============================] - 619s 3s/step - loss: 0.2970 - accuracy: 0.9001 - precision: 0.9540 - recall: 0.8672 - get_f1: 0.9084 - jaccard_score: 0.9972 - auc: 0.9916 - categorical_accuracy: 0.9001 - categorical_crossentropy: 0.2970 - categorical_hinge: 0.2249 - val_loss: 0.3602 - val_accuracy: 0.8837 - val_precision: 0.9425 - val_recall: 0.8567 - val_get_f1: 0.8974 - val_jaccard_score: 0.9970 - val_auc: 0.9875 - val_categorical_accuracy: 0.8837 - val_categorical_crossentropy: 0.3602 - val_categorical_hinge: 0.2442
# Epoch 9/50
# 217/217 [==============================] - 601s 3s/step - loss: 0.2638 - accuracy: 0.9112 - precision: 0.9577 - recall: 0.8822 - get_f1: 0.9184 - jaccard_score: 0.9975 - auc: 0.9932 - categorical_accuracy: 0.9112 - categorical_crossentropy: 0.2638 - categorical_hinge: 0.2044 - val_loss: 0.3052 - val_accuracy: 0.8965 - val_precision: 0.9353 - val_recall: 0.8766 - val_get_f1: 0.9049 - val_jaccard_score: 0.9974 - val_auc: 0.9907 - val_categorical_accuracy: 0.8965 - val_categorical_crossentropy: 0.3052 - val_categorical_hinge: 0.2171
# Epoch 10/50
# 217/217 [==============================] - 603s 3s/step - loss: 0.2486 - accuracy: 0.9146 - precision: 0.9584 - recall: 0.8872 - get_f1: 0.9214 - jaccard_score: 0.9976 - auc: 0.9940 - categorical_accuracy: 0.9146 - categorical_crossentropy: 0.2486 - categorical_hinge: 0.1955 - val_loss: 0.3174 - val_accuracy: 0.8964 - val_precision: 0.9216 - val_recall: 0.8816 - val_get_f1: 0.9011 - val_jaccard_score: 0.9975 - val_auc: 0.9901 - val_categorical_accuracy: 0.8964 - val_categorical_crossentropy: 0.3174 - val_categorical_hinge: 0.2176
# Epoch 11/50
# 217/217 [==============================] - 604s 3s/step - loss: 0.2130 - accuracy: 0.9267 - precision: 0.9639 - recall: 0.9054 - get_f1: 0.9337 - jaccard_score: 0.9980 - auc: 0.9955 - categorical_accuracy: 0.9267 - categorical_crossentropy: 0.2130 - categorical_hinge: 0.1676 - val_loss: 0.3852 - val_accuracy: 0.8867 - val_precision: 0.9343 - val_recall: 0.8711 - val_get_f1: 0.9015 - val_jaccard_score: 0.9973 - val_auc: 0.9861 - val_categorical_accuracy: 0.8867 - val_categorical_crossentropy: 0.3852 - val_categorical_hinge: 0.2241
# Epoch 12/50
# 217/217 [==============================] - 603s 3s/step - loss: 0.1954 - accuracy: 0.9336 - precision: 0.9672 - recall: 0.9132 - get_f1: 0.9393 - jaccard_score: 0.9981 - auc: 0.9961 - categorical_accuracy: 0.9336 - categorical_crossentropy: 0.1954 - categorical_hinge: 0.1563 - val_loss: 0.2754 - val_accuracy: 0.9108 - val_precision: 0.9560 - val_recall: 0.8867 - val_get_f1: 0.9199 - val_jaccard_score: 0.9978 - val_auc: 0.9920 - val_categorical_accuracy: 0.9108 - val_categorical_crossentropy: 0.2754 - val_categorical_hinge: 0.1823
# Epoch 13/50
# 217/217 [==============================] - 602s 3s/step - loss: 0.1781 - accuracy: 0.9397 - precision: 0.9693 - recall: 0.9208 - get_f1: 0.9444 - jaccard_score: 0.9983 - auc: 0.9968 - categorical_accuracy: 0.9397 - categorical_crossentropy: 0.1781 - categorical_hinge: 0.1433 - val_loss: 0.2486 - val_accuracy: 0.9226 - val_precision: 0.9541 - val_recall: 0.9046 - val_get_f1: 0.9287 - val_jaccard_score: 0.9980 - val_auc: 0.9927 - val_categorical_accuracy: 0.9226 - val_categorical_crossentropy: 0.2486 - val_categorical_hinge: 0.1644
# Epoch 14/50
# 217/217 [==============================] - 606s 3s/step - loss: 0.1629 - accuracy: 0.9460 - precision: 0.9738 - recall: 0.9274 - get_f1: 0.9499 - jaccard_score: 0.9984 - auc: 0.9972 - categorical_accuracy: 0.9460 - categorical_crossentropy: 0.1629 - categorical_hinge: 0.1328 - val_loss: 0.3038 - val_accuracy: 0.9097 - val_precision: 0.9495 - val_recall: 0.8970 - val_get_f1: 0.9225 - val_jaccard_score: 0.9979 - val_auc: 0.9900 - val_categorical_accuracy: 0.9097 - val_categorical_crossentropy: 0.3038 - val_categorical_hinge: 0.1783
# Epoch 15/50
# 217/217 [==============================] - 600s 3s/step - loss: 0.1526 - accuracy: 0.9474 - precision: 0.9726 - recall: 0.9321 - get_f1: 0.9518 - jaccard_score: 0.9985 - auc: 0.9975 - categorical_accuracy: 0.9474 - categorical_crossentropy: 0.1526 - categorical_hinge: 0.1239 - val_loss: 0.2490 - val_accuracy: 0.9219 - val_precision: 0.9596 - val_recall: 0.9019 - val_get_f1: 0.9298 - val_jaccard_score: 0.9981 - val_auc: 0.9928 - val_categorical_accuracy: 0.9219 - val_categorical_crossentropy: 0.2490 - val_categorical_hinge: 0.1611
# Epoch 16/50
# 217/217 [==============================] - 603s 3s/step - loss: 0.1377 - accuracy: 0.9535 - precision: 0.9762 - recall: 0.9380 - get_f1: 0.9566 - jaccard_score: 0.9986 - auc: 0.9979 - categorical_accuracy: 0.9535 - categorical_crossentropy: 0.1377 - categorical_hinge: 0.1145 - val_loss: 0.2753 - val_accuracy: 0.9158 - val_precision: 0.9532 - val_recall: 0.9017 - val_get_f1: 0.9267 - val_jaccard_score: 0.9980 - val_auc: 0.9911 - val_categorical_accuracy: 0.9158 - val_categorical_crossentropy: 0.2753 - val_categorical_hinge: 0.1651
# Epoch 17/50
# 217/217 [==============================] - 602s 3s/step - loss: 0.1312 - accuracy: 0.9559 - precision: 0.9765 - recall: 0.9416 - get_f1: 0.9587 - jaccard_score: 0.9987 - auc: 0.9982 - categorical_accuracy: 0.9559 - categorical_crossentropy: 0.1312 - categorical_hinge: 0.1090 - val_loss: 0.2602 - val_accuracy: 0.9224 - val_precision: 0.9533 - val_recall: 0.9033 - val_get_f1: 0.9275 - val_jaccard_score: 0.9981 - val_auc: 0.9917 - val_categorical_accuracy: 0.9224 - val_categorical_crossentropy: 0.2602 - val_categorical_hinge: 0.1609
# Epoch 18/50
# 217/217 [==============================] - ETA: 0s - loss: 0.1248 - accuracy: 0.9567 - precision: 0.9774 - recall: 0.9437 - get_f1: 0.9603 - jaccard_score: 0.9988 - auc: 0.9982 - categorical_accuracy: 0.9567 - categorical_crossentropy: 0.1248 - categorical_hinge: 0.1043Restoring model weights from the end of the best epoch: 13.
# 217/217 [==============================] - 608s 3s/step - loss: 0.1248 - accuracy: 0.9567 - precision: 0.9774 - recall: 0.9437 - get_f1: 0.9603 - jaccard_score: 0.9988 - auc: 0.9982 - categorical_accuracy: 0.9567 - categorical_crossentropy: 0.1248 - categorical_hinge: 0.1043 - val_loss: 0.2967 - val_accuracy: 0.9206 - val_precision: 0.9460 - val_recall: 0.9083 - val_get_f1: 0.9267 - val_jaccard_score: 0.9982 - val_auc: 0.9890 - val_categorical_accuracy: 0.9206 - val_categorical_crossentropy: 0.2967 - val_categorical_hinge: 0.1598
# Epoch 18: early stopping
# CPU times: user 5h 19min 11s, sys: 16min 35s, total: 5h 35min 46s
# Wall time: 3h 6min 47s

# %%
model.save(PATH + lang +'/models/ann/' + architecture + '_' + vector + '_30k_300d_' + optimizer_name + '_' + lang + '/')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.

# %%
# %%time
results = model.evaluate(X_test, y_test)
results[len(results) - 1] = execution_time
# Out:
# 372/372 [==============================] - 114s 307ms/step - loss: 0.2486 - accuracy: 0.9226 - precision: 0.9541 - recall: 0.9046 - get_f1: 0.9284 - jaccard_score: 0.9980 - auc: 0.9927 - categorical_accuracy: 0.9226 - categorical_crossentropy: 0.2486 - categorical_hinge: 0.1644
# CPU times: user 3min 4s, sys: 13.3 s, total: 3min 17s
# Wall time: 2min 21s

# %%
pickle.dump(results,open(PATH + lang + '/results/' + architecture + '_' + vector + '_30k_300d_' + optimizer_name + '_' + lang, 'wb'))

# %%
print("Test Loss: {:.2f}%".format(results[0] * 100))
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
print("Test Precision: {:.2f}%".format(results[2] * 100))
print("Test Recall: {:.2f}%".format(results[3] * 100))
print("Test F-1 Score: {:.2f}%".format(results[4] * 100))
print("Test Jaccard Score: {:.2f}%".format(results[5] * 100))
print("Test AUC ar ROC līkni: {:.2f}%".format(results[6] * 100))
print("Test Categorical Accuracy: {:.2f}%".format(results[7] * 100))
print("Test Categorical Crossentropy: {:.2f}%".format(results[8] * 100))
print("Test Categorical Hinge: {:.2f}%".format(results[9] * 100))
print("Execution time: {:f}".format(results[len(results)-1]))
# Out:
# Test Loss: 24.86%
# Test Accuracy: 92.26%
# Test Precision: 95.41%
# Test Recall: 90.46%
# Test F-1 Score: 92.84%
# Test Jaccard Score: 99.80%
# Test AUC ar ROC līkni: 99.27%
# Test Categorical Accuracy: 92.26%
# Test Categorical Crossentropy: 24.86%
# Test Categorical Hinge: 1120784.34%
# Execution time: 11207.843415

# %%
graph_data = pd.DataFrame(estimator.history)

# %%
pickle.dump(graph_data,open(PATH + lang + '/graph_data/' + architecture + '_' + vector + '_30k_300d_' + optimizer_name + '_' + lang, 'wb'))

# %%
# %%time
plt.style.use('ggplot')
graph_data.plot()
# Out:
# CPU times: user 67.6 ms, sys: 5.91 ms, total: 73.5 ms
# Wall time: 92.8 ms
