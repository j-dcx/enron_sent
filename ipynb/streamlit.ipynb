# %%
#https://colab.research.google.com/github/hamletbatista/sej/blob/master/Streamlit_Demo.ipynb#scrollTo=XlId-62RmVAe

# %%
# %%capture
# !pip install -U streamlit opencv-python

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/final/enron_sent'
# Out:
# /content/drive/MyDrive/Colab Notebooks/final/enron_sent

# %%
# !pip install gensim -q -U
# Out:
#      |████████████████████████████████| 24.1 MB 1.6 MB/s

# %%
import gensim

# %%
gensim.__version__
# Out:
# '4.2.0'

# %%
# %%bash --bg
# streamlit run enron_sent.py > debug.log 2>&1

# %%
# !tail debug.log

# %%
# %%capture
#https://ngrok.com/download
#!wget https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-linux-amd64.tgz && unzip ngrok-stable-linux-amd64.zip
#!tar xvzf ngrok-v3-stable-linux-amd64.tgz
import os
os.chmod('/content/drive/MyDrive/Colab Notebooks/final/enron_sent/ngrok', 0o777)

# !./ngrok authtoken [your token here]

# %%
# !killall ./ngrok

# %%
# %%bash --bg
# ./ngrok http 172.28.0.2:8501 > ngrok.log 2>&1

# %%
# !tail ngrok.log

# %%
# !curl -s http://localhost:4040/api/tunnels

# %%
# %%capture
#https://stedolan.github.io/jq/tutorial/
# !apt-get install jq

# %%
# !curl -s http://localhost:4040/api/tunnels | jq ".tunnels[0].public_url"
